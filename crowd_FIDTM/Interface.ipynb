# %% [markdown]
# # 개발환경(권장)
# - python >=3.6
# - pytorch >=1.4
# - opencv-python >=4.0
# - scipy >=1.4.0
# - h5py >=2.10
# - pillow >=7.0.0
# - imageio >=1.18
# - nni >=2.0 (python3 -m pip install --upgrade nni)

# %% [markdown]
# ## install

# %% [markdown]
# ### cuda 10.1 삭제

# %%
# !nvcc -V
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2020 NVIDIA Corporation
# Built on Mon_Oct_12_20:09:46_PDT_2020
# Cuda compilation tools, release 11.1, V11.1.105
# Build cuda_11.1.TC455_06.29190527_0

# %%
# !apt-get --purge remove cuda nvidia* libnvidia-*
# !dpkg -l | grep cuda- | awk '{print $2}' | xargs -n1 dpkg --purge
# !apt-get remove cuda-*
# !apt autoremove
# !apt-get update

# %% [markdown]
# ### cuda 10.1 설치

# %%
# !wget https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64/cuda-ubuntu1804.pin
# !sudo mv cuda-ubuntu1804.pin /etc/apt/preferences.d/cuda-repository-pin-600
# !sudo apt-key adv --fetch-keys https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64/7fa2af80.pub
# !sudo add-apt-repository "deb https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64/ /"
# !apt-get update
# !apt-get -y install cuda-10.1

# %%
# !nvcc -V
# !nvidia-smi
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2020 NVIDIA Corporation
# Built on Mon_Oct_12_20:09:46_PDT_2020
# Cuda compilation tools, release 11.1, V11.1.105
# Build cuda_11.1.TC455_06.29190527_0
# Thu Apr 14 15:48:10 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   36C    P0    27W / 250W |      0MiB / 16280MiB |      0%      Default |
# ...

# %% [markdown]
# ### 패키지 설치

# %%
# python
# !pip install python==3.6
# pythorch(CUDA와 세트)
# !pip uninstall torch torchvision
# !pip install torch==1.4.0 torchvision==0.5.0
    # # CUDA 10.1
    # pip install torch==1.4.0 torchvision==0.5.0

    # # CUDA 9.2
    # pip install torch==1.4.0+cu92 torchvision==0.5.0+cu92 -f https://download.pytorch.org/whl/torch_stable.html

    # # CPU only
    # pip install torch==1.4.0+cpu torchvision==0.5.0+cpu -f https://download.pytorch.org/whl/torch_stable.html

    # https://developer.nvidia.com/cuda-toolkit-archive 지포스 CUDA 설치

# opencv-python 
# !pip install opencv-python==4.0.1.24
# scipy
# !pip install scipy==1.4.0
# h5py
# !pip install h5py==2.10
# pillow
# !pip install PIL===7.0.0
# imageio
# !pip install imageio==1.18
# nni
# !pip install nni==2.0

# %% [markdown]
# ### nni 설치

# %%
# !pip install nni==2.0
# Out:
# ...
#      |████████████████████████████████| 40.7 MB 1.2 MB/s
# ...
#      |████████████████████████████████| 111 kB 45.2 MB/s
# ...
#      |████████████████████████████████| 109 kB 25.9 MB/s
# ...
#      |████████████████████████████████| 130 kB 57.4 MB/s
# ...
#      |████████████████████████████████| 127 kB 69.6 MB/s
# ...
#      |████████████████████████████████| 546 kB 55.9 MB/s
# ...
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# ...

# %% [markdown]
# ## Version_Check

# %%
import sys
print('python_ver : ', sys.version)
import torch
print('torch_ver : ', torch.__version__)
import cv2
print('openCV_ver : ', cv2.__version__)
import scipy
print('scipy_ver : ', scipy.__version__)
import h5py
print('h5py_ver : ', h5py.__version__)
import PIL
print('pillow_ver : ', PIL.__version__)
import imageio
print('imageio_ver : ', imageio.__version__)
import nni
print('nni_ver : ', nni.__version__)
# Out:
# python_ver :  3.7.13 (default, Mar 16 2022, 17:37:17)
# [GCC 7.5.0]
# torch_ver :  1.10.0+cu111
# openCV_ver :  4.1.2
# scipy_ver :  1.4.1
# h5py_ver :  3.1.0
# pillow_ver :  7.1.2
# imageio_ver :  2.4.1
# nni_ver :  2.0

# %% [markdown]
# # Import

# %%
# !pip install ipynb-py-convert
# Out:
# ...
#   Created wheel for ipynb-py-convert: filename=ipynb_py_convert-0.4.6-py3-none-any.whl size=4640 sha256=816e0672ebfbd6189daa8eb47d5a31267c1e2e59e3cb55c456cb4f47e6bbdb05
#   Stored in directory: /root/.cache/pip/wheels/af/31/a9/761b134adbbca3c92d491eff3bad785c0a0c0079695d6f0504
# Successfully built ipynb-py-convert
# ...

# %%
# !ipynb-py-convert test.py test_1.ipynb

# %%
import numpy as np
test = np.load('./npydata/jhu_test.npy', encoding='latin1')
print(test)
# Out:
# ['/content/drive/MyDrive/FIDTM/dataset/jhu_crowd_v2.0/test/images_2048/0002.jpg'
#  '/content/drive/MyDrive/FIDTM/dataset/jhu_crowd_v2.0/test/images_2048/0004.jpg'
#  '/content/drive/MyDrive/FIDTM/dataset/jhu_crowd_v2.0/test/images_2048/0005.jpg'
#  ...
#  '/content/drive/MyDrive/FIDTM/dataset/jhu_crowd_v2.0/test/images_2048/4375.jpg'
#  '/content/drive/MyDrive/FIDTM/dataset/jhu_crowd_v2.0/test/images_2048/4376.jpg'
#  '/content/drive/MyDrive/FIDTM/dataset/jhu_crowd_v2.0/test/images_2048/4378.jpg']

# %%
gt_file = h5py.File('/content/drive/MyDrive/FIDTM/dataset/ShanghaiTech/part_A_final/test_data/gt_fidt_map/IMG_1.h5')
display(gt_file.values())
print(gt_file.keys())
print(gt_file['kpoint'])
print(gt_file['fidt_map'])
# Out:
# ValuesViewHDF5(<HDF5 file "IMG_1.h5" (mode r)>)
# <KeysViewHDF5 ['fidt_map', 'kpoint']>
# <HDF5 dataset "kpoint": shape (704, 1024), type "<f8">
# <HDF5 dataset "fidt_map": shape (704, 1024), type "<f4">
